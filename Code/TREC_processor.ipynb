# %% [markdown]
# ### __TREC__

# %% [markdown]
# Removes the label-fine column in the TREC train data set as it is not needed in the project.
# Splits the data into train and test sets and exports them

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import random

# %%
TREC_dir = '../Datasets/TREC_dataset/'
train = f'{TREC_dir}/train.csv'

# %%
df = pd.read_csv(train)
df
# Out:
#       label-coarse  label-fine  \
# 0                0           0
# 1                1           1
# 2                0           0
# 3                1           2
# 4                2           3
# ...            ...         ...
# 5447             1          14
# 5448             1          46
# 5449             4          41
# 5450             4          41
# 5451             1          46
#
#                                                    text
# 0     How did serfdom develop in and then leave Russ...
# 1      What films featured the character Popeye Doyle ?
# 2     How can I find a list of celebrities ' real na...
# 3     What fowl grabs the spotlight after the Chines...
# 4                       What is the full form of .com ?
# ...                                                 ...
# 5447            What 's the shape of a camel 's spine ?
# 5448           What type of currency is used in China ?
# 5449                    What is the temperature today ?
# 5450              What is the temperature for cooking ?
# 5451               What currency is used in Australia ?
#
# [5452 rows x 3 columns]

# %%
df = df.drop(columns=['label-fine'])
df
# Out:
#       label-coarse                                               text
# 0                0  How did serfdom develop in and then leave Russ...
# 1                1   What films featured the character Popeye Doyle ?
# 2                0  How can I find a list of celebrities ' real na...
# 3                1  What fowl grabs the spotlight after the Chines...
# 4                2                    What is the full form of .com ?
# ...            ...                                                ...
# 5447             1            What 's the shape of a camel 's spine ?
# 5448             1           What type of currency is used in China ?
# 5449             4                    What is the temperature today ?
# 5450             4              What is the temperature for cooking ?
# 5451             1               What currency is used in Australia ?
#
# [5452 rows x 2 columns]

# %%
# Get list of unique label-coarse
labels = df['label-coarse'].unique() # returns an array([])
labels = list(labels) 
labels
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
# select 2 random choices
choices = random.sample(labels, 2)
choices
# Out:
# [4, 2]

# %%
new_df = df.copy()
new_df

for index, row in new_df.iterrows():
    label_coarse = new_df.loc[index, 'label-coarse']
    if label_coarse in choices:
        new_df.loc[index, 'label-coarse'] = 'OTHERS'

new_df
# Out:
# /var/folders/6z/3qnf32vj11l8tc1c14pl2rhc0000gn/T/ipykernel_21125/3129126962.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'OTHERS' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   new_df.loc[index, 'label-coarse'] = 'OTHERS'
#      label-coarse                                               text
# 0               0  How did serfdom develop in and then leave Russ...
# 1               1   What films featured the character Popeye Doyle ?
# 2               0  How can I find a list of celebrities ' real na...
# 3               1  What fowl grabs the spotlight after the Chines...
# 4          OTHERS                    What is the full form of .com ?
# ...           ...                                                ...
# 5447            1            What 's the shape of a camel 's spine ?
# 5448            1           What type of currency is used in China ?
# 5449       OTHERS                    What is the temperature today ?
# 5450       OTHERS              What is the temperature for cooking ?
# 5451            1               What currency is used in Australia ?
#
# [5452 rows x 2 columns]

# %%
# Split the DataFrame into training and test sets
train_df, test_df = train_test_split(new_df, test_size=0.2, shuffle=True)
train_df_rest, train_df_dev = train_test_split(train_df, test_size=500, shuffle=True)

print("Training set (dev):")
print(train_df_dev)

print("Training set:")
print(train_df_rest)

print("\nTest set:")
print(test_df)
# Out:
# Training set (dev):
#      label-coarse                                               text
# 3911       OTHERS     Hitler came to power in Germany in what year ?
# 4453            3                   What company produces Spumante ?
# 3631            0                         Why is hockey so violent ?
# 427             1                     What kind of animal is Babar ?
# 444             0                  What does Inuit and Eskimo mean ?
# ...           ...                                                ...
# 1556            3                        Who wrote Sons and Lovers ?
# 1168       OTHERS  What phone number can I call to have a tree pl...
# 1297            0                        What are amicable numbers ?
# 2558            5  What country was Brian Boru an 11th-century ki...
# 385             5  What 's the closest G2 Spectrum Yellow Dwarf t...
#
# [3861 rows x 2 columns]
# Training set:
#      label-coarse                                               text
# 1552            5  What African country is governed from Ouagadou...
# 1073       OTHERS  How many Grammys did Michael Jackson win in 19...
# 2203            3    What was the first U.S.-based team in the NHL ?
# 76              3  What 19th-century painter died in the Marquesa...
# 3928            3                         Who was Ezra Taft Benson ?
# ...           ...                                                ...
# 2519            5                     Name a civil war battlefield .
# 1035            5                        Where is Tufts University ?
# 5136            1  What 's the traditional drink at the Kentucky ...
# 4970            3  What kind of women gave Sigmund Freud erotic d...
# 2744            5  What desert country borders Saudi Arabia , Ira...
#
# [500 rows x 2 columns]
#
# Test set:
#      label-coarse                                               text
# 3720            1                      What is a fear of rejection ?
# 1093            1                         What is Jell-O made from ?
# 1881       OTHERS  How many presidents have died on the 4th of Ju...
# 3960            1                            What color is Chablis ?
# 3118            0  What are some chemical properties of mendelevi...
# ...           ...                                                ...
# 4055       OTHERS  How long is the world 's largest ship , in met...
# 4700            1  What are some translations of the phrase `` Th...
# 1413            1  What 1963 Joseph L. Mankiewicz film cost $28 m...
# 4127            5                    What 's the capital of Monaco ?
# 4732            3                          Who wrote The Godfather ?
#
# [1091 rows x 2 columns]

# %%
path = '../Datasets/Processed/TREC/'

# Export DataFrame to a CSV file
train_df_rest.to_csv(f'{path}train.csv', index=False)
train_df_dev.to_csv(f'{path}train.dev.csv', index=False)
test_df.to_csv(f'{path}test.csv', index=False)
